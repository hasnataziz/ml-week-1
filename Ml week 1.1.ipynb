# %%
import pandas as pd

# %%
Iris = pd.read_csv("Iris.csv")
Iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
Iris.head(3)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
Iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
Iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
Iris.value_counts()
# Out:
# Id   SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 1    5.1            3.5           1.4            0.2           Iris-setosa        1
# 95   5.6            2.7           4.2            1.3           Iris-versicolor    1
# 97   5.7            2.9           4.2            1.3           Iris-versicolor    1
# 98   6.2            2.9           4.3            1.3           Iris-versicolor    1
# 99   5.1            2.5           3.0            1.1           Iris-versicolor    1
#                                                                                  ..
# 51   7.0            3.2           4.7            1.4           Iris-versicolor    1
# 52   6.4            3.2           4.5            1.5           Iris-versicolor    1
# 53   6.9            3.1           4.9            1.5           Iris-versicolor    1
# 54   5.5            2.3           4.0            1.3           Iris-versicolor    1
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(Iris["Id"],bins = 20)
plt.figure(figsize=(10,6))
plt.show()

# %%
plt.hist(Iris["SepalLengthCm"],bins = 20)
plt.figure(figsize=(10,6))
plt.show()

# %%
plt.hist(Iris["SepalWidthCm"],bins = 20)
plt.figure(figsize=(10,6))
plt.show()

# %%
plt.hist(Iris["PetalLengthCm"],bins = 20)
plt.figure(figsize=(10,6))
plt.show()

# %%
plt.hist(Iris["PetalWidthCm"],bins = 20)
plt.figure(figsize=(10,6))
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
Iris = pd.read_csv("Iris.csv")
Iris = Iris.drop(columns=["Id"])
#to show the relationship between the features
#for individual
#sns.scatterplot(data=df, x='SepalLengthCm', y='SepalWidthCm', hue='Species')
#sns.scatterplot(data=df, x='PetalLengthCm', y='PetalWidthCm', hue='Species')
#sns.scatterplot(data=df, x='SepalLengthCm', y='PetalLengthCm', hue='Species')
#sns.scatterplot(data=df, x='SepalWidthCm', y='PetalWidthCm', hue='Species')


# Load the dataset





# If you want to create individual scatter plots, you can do it like this:
# Scatter plot between SepalLengthCm and SepalWidthCm
plt.figure(figsize=(10, 6))
sns.scatterplot(data=Iris, x='SepalLengthCm', y='SepalWidthCm', hue='Species')
plt.title('Scatter plot between Sepal Length and Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# Scatter plot between PetalLengthCm and PetalWidthCm
plt.figure(figsize=(10, 6))
sns.scatterplot(data=Iris, x='PetalLengthCm', y='PetalWidthCm', hue='Species')
plt.title('Scatter plot between Petal Length and Petal Width')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.show()

# Scatter plot between SepalLengthCm and PetalLengthCm
plt.figure(figsize=(10, 6))
sns.scatterplot(data=Iris, x='SepalLengthCm', y='PetalLengthCm', hue='Species')
plt.title('Scatter plot between Sepal Length and Petal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.show()

# Scatter plot between SepalWidthCm and PetalWidthCm
plt.figure(figsize=(10, 6))
sns.scatterplot(data=Iris, x='SepalWidthCm', y='PetalWidthCm', hue='Species')
plt.title('Scatter plot between Sepal Width and Petal Width')
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Petal Width (cm)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
Iris = pd.read_csv("Iris.csv")
Iris = Iris.drop(columns=["Id"])
#to show the relationship between the features
sns.pairplot(Iris, hue="Species")
plt.show()
# Out:
# C:\Users\.PY\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\.PY\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\.PY\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
